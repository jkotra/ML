# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

import lightgbm as gbm

# %%
#read dataset

data = pd.read_csv("/home/jagadeesh/datasets/diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
trn_x, val_x, trn_y, val_y = train_test_split(data.drop('Outcome',axis=1).values,data.Outcome.values,test_size=0.10)

# %%
kfold = 3
skf = StratifiedKFold(n_splits=kfold, random_state=1)

for i, (train_index, test_index) in enumerate(skf.split(trn_x, trn_y)):
    
    trn_dataset = gbm.Dataset(trn_x[train_index],trn_y[train_index])
    val_dataset = gbm.Dataset(trn_x[test_index],trn_y[test_index])

    parameters = {
    "objective": "binary",
     }

    clf = gbm.train(parameters,trn_dataset,valid_sets=val_dataset,early_stopping_rounds=25)
# Out:
# [1]	valid_0's binary_logloss: 0.620875
# Training until validation scores don't improve for 25 rounds.
# [2]	valid_0's binary_logloss: 0.598073
# [3]	valid_0's binary_logloss: 0.579301
# [4]	valid_0's binary_logloss: 0.565131
# [5]	valid_0's binary_logloss: 0.549834
# [6]	valid_0's binary_logloss: 0.540157
# [7]	valid_0's binary_logloss: 0.533258
# [8]	valid_0's binary_logloss: 0.526259
# [9]	valid_0's binary_logloss: 0.522363
# [10]	valid_0's binary_logloss: 0.520407
# [11]	valid_0's binary_logloss: 0.512858
# [12]	valid_0's binary_logloss: 0.509354
# [13]	valid_0's binary_logloss: 0.507472
# [14]	valid_0's binary_logloss: 0.506525
# [15]	valid_0's binary_logloss: 0.507668
# [16]	valid_0's binary_logloss: 0.505267
# [17]	valid_0's binary_logloss: 0.50735
# [18]	valid_0's binary_logloss: 0.507533
# [19]	valid_0's binary_logloss: 0.507683
# [20]	valid_0's binary_logloss: 0.508318
# [21]	valid_0's binary_logloss: 0.510589
# [22]	valid_0's binary_logloss: 0.509133
# [23]	valid_0's binary_logloss: 0.510789
# [24]	valid_0's binary_logloss: 0.514617
# [25]	valid_0's binary_logloss: 0.516182
# [26]	valid_0's binary_logloss: 0.517141
# [27]	valid_0's binary_logloss: 0.518095
# [28]	valid_0's binary_logloss: 0.52158
# [29]	valid_0's binary_logloss: 0.524351
# [30]	valid_0's binary_logloss: 0.525157
# [31]	valid_0's binary_logloss: 0.529156
# [32]	valid_0's binary_logloss: 0.528841
# [33]	valid_0's binary_logloss: 0.530552
# [34]	valid_0's binary_logloss: 0.531014
# [35]	valid_0's binary_logloss: 0.528514
# [36]	valid_0's binary_logloss: 0.531241
# [37]	valid_0's binary_logloss: 0.530988
# [38]	valid_0's binary_logloss: 0.528741
# [39]	valid_0's binary_logloss: 0.530812
# [40]	valid_0's binary_logloss: 0.531168
# [41]	valid_0's binary_logloss: 0.53217
# Early stopping, best iteration is:
# [16]	valid_0's binary_logloss: 0.505267
# ***************
# [1]	valid_0's binary_logloss: 0.618391
# Training until validation scores don't improve for 25 rounds.
# [2]	valid_0's binary_logloss: 0.59447
# [3]	valid_0's binary_logloss: 0.570529
# [4]	valid_0's binary_logloss: 0.552939
# [5]	valid_0's binary_logloss: 0.538499
# [6]	valid_0's binary_logloss: 0.526769
# [7]	valid_0's binary_logloss: 0.518384
# [8]	valid_0's binary_logloss: 0.510921
# [9]	valid_0's binary_logloss: 0.502533
# [10]	valid_0's binary_logloss: 0.495778
# [11]	valid_0's binary_logloss: 0.488754
# [12]	valid_0's binary_logloss: 0.486232
# [13]	valid_0's binary_logloss: 0.481317
# [14]	valid_0's binary_logloss: 0.480556
# [15]	valid_0's binary_logloss: 0.478815
# [16]	valid_0's binary_logloss: 0.477816
# [17]	valid_0's binary_logloss: 0.477177
# [18]	valid_0's binary_logloss: 0.474037
# [19]	valid_0's binary_logloss: 0.475868
# [20]	valid_0's binary_logloss: 0.473238
# [21]	valid_0's binary_logloss: 0.469494
# [22]	valid_0's binary_logloss: 0.469215
# [23]	valid_0's binary_logloss: 0.469295
# [24]	valid_0's binary_logloss: 0.470569
# [25]	valid_0's binary_logloss: 0.471776
# [26]	valid_0's binary_logloss: 0.470845
# [27]	valid_0's binary_logloss: 0.470726
# [28]	valid_0's binary_logloss: 0.470658
# [29]	valid_0's binary_logloss: 0.475399
# [30]	valid_0's binary_logloss: 0.475402
# [31]	valid_0's binary_logloss: 0.474282
# [32]	valid_0's binary_logloss: 0.477676
# [33]	valid_0's binary_logloss: 0.477331
# [34]	valid_0's binary_logloss: 0.475932
# [35]	valid_0's binary_logloss: 0.47676
# [36]	valid_0's binary_logloss: 0.478858
# [37]	valid_0's binary_logloss: 0.479905
# [38]	valid_0's binary_logloss: 0.480086
# [39]	valid_0's binary_logloss: 0.477765
# [40]	valid_0's binary_logloss: 0.479534
# [41]	valid_0's binary_logloss: 0.481309
# [42]	valid_0's binary_logloss: 0.482627
# [43]	valid_0's binary_logloss: 0.483947
# [44]	valid_0's binary_logloss: 0.482721
# [45]	valid_0's binary_logloss: 0.484674
# [46]	valid_0's binary_logloss: 0.486538
# [47]	valid_0's binary_logloss: 0.485238
# Early stopping, best iteration is:
# [22]	valid_0's binary_logloss: 0.469215
# ***************
# [1]	valid_0's binary_logloss: 0.621902
# Training until validation scores don't improve for 25 rounds.
# [2]	valid_0's binary_logloss: 0.598708
# [3]	valid_0's binary_logloss: 0.579166
# [4]	valid_0's binary_logloss: 0.563695
# [5]	valid_0's binary_logloss: 0.546136
# [6]	valid_0's binary_logloss: 0.531164
# [7]	valid_0's binary_logloss: 0.520028
# [8]	valid_0's binary_logloss: 0.508959
# [9]	valid_0's binary_logloss: 0.503408
# [10]	valid_0's binary_logloss: 0.493948
# [11]	valid_0's binary_logloss: 0.490388
# [12]	valid_0's binary_logloss: 0.485489
# [13]	valid_0's binary_logloss: 0.483453
# [14]	valid_0's binary_logloss: 0.478151
# [15]	valid_0's binary_logloss: 0.473393
# [16]	valid_0's binary_logloss: 0.470671
# [17]	valid_0's binary_logloss: 0.469562
# [18]	valid_0's binary_logloss: 0.468917
# [19]	valid_0's binary_logloss: 0.469683
# [20]	valid_0's binary_logloss: 0.468836
# [21]	valid_0's binary_logloss: 0.470881
# [22]	valid_0's binary_logloss: 0.468238
# [23]	valid_0's binary_logloss: 0.470273
# [24]	valid_0's binary_logloss: 0.469097
# [25]	valid_0's binary_logloss: 0.470822
# [26]	valid_0's binary_logloss: 0.473509
# [27]	valid_0's binary_logloss: 0.475429
# [28]	valid_0's binary_logloss: 0.478477
# [29]	valid_0's binary_logloss: 0.480407
# [30]	valid_0's binary_logloss: 0.480647
# [31]	valid_0's binary_logloss: 0.481317
# [32]	valid_0's binary_logloss: 0.482437
# [33]	valid_0's binary_logloss: 0.485427
# [34]	valid_0's binary_logloss: 0.487575
# [35]	valid_0's binary_logloss: 0.488509
# [36]	valid_0's binary_logloss: 0.489599
# [37]	valid_0's binary_logloss: 0.488919
# [38]	valid_0's binary_logloss: 0.489961
# [39]	valid_0's binary_logloss: 0.489528
# [40]	valid_0's binary_logloss: 0.494025
# [41]	valid_0's binary_logloss: 0.496238
# [42]	valid_0's binary_logloss: 0.498379
# [43]	valid_0's binary_logloss: 0.500667
# [44]	valid_0's binary_logloss: 0.504401
# [45]	valid_0's binary_logloss: 0.506884
# [46]	valid_0's binary_logloss: 0.507535
# [47]	valid_0's binary_logloss: 0.51148
# Early stopping, best iteration is:
# [22]	valid_0's binary_logloss: 0.468238
# ***************

# %%
from sklearn.metrics import accuracy_score

rounder = lambda x: 1 if x > 0.51 else 0

predicted = []

for p in clf.predict(val_x):
    predicted.append(rounder(p))
    
accuracy_score(val_y, predicted)
# Out:
# 0.7142857142857143
